# %%
from projekt import Maze

maze = Maze(50,"smiley")
path = Maze.shortest_path(maze)
Maze.maze_picture(maze, path)

# %%
maze_instance= Maze()
maze_instance= load_maze("data//maze_5.csv")
path = maze_instance.shortest_path()
maze_instance.maze_picture(path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_258886/3667209381.py in <module>
# ----> 1 maze_instance= Maze.load_maze("data//maze_1.csv")
#       2 maze_instance= Maze.load_maze("data//maze_5.csv")
#       3 path = maze_instance.shortest_path()
#       4 maze_instance.maze_picture(path)
#
# TypeError: Maze.load_maze() missing 1 required positional argument: 'file'

# %%
maze = Maze(50,"x")
path = Maze.shortest_path(maze)
Maze.maze_picture(maze, path)

# %%
maze = Maze(50,"cross")
path = Maze.shortest_path(maze)
Maze.maze_picture(maze, path)
incident_matrix = Maze.IncidentMatrix(maze)
